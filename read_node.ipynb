# %%
import vp4jl

# %%
import json

# %%
import os

# %%
vp4jl.__file__
# Out:
# '/srv/conda/envs/notebook/lib/python3.10/site-packages/vp4jl/__init__.py'

# %%
vp4jl_path = os.path.dirname(vp4jl.__file__)
vp4jl_path
# Out:
# '/srv/conda/envs/notebook/lib/python3.10/site-packages/vp4jl'

# %%
node_path = os.path.join(vp4jl_path, "nodeextension")
node_path
# Out:
# '/srv/conda/envs/notebook/lib/python3.10/site-packages/vp4jl/nodeextension'

# %%
nodes_lst = [os.path.join(node_path, f) for f in os.listdir(node_path) if f.endswith(".json")]
nodes_lst
# Out:
# ['/srv/conda/envs/notebook/lib/python3.10/site-packages/vp4jl/nodeextension/keras.json',
#  '/srv/conda/envs/notebook/lib/python3.10/site-packages/vp4jl/nodeextension/numpy.json',
#  '/srv/conda/envs/notebook/lib/python3.10/site-packages/vp4jl/nodeextension/Path.json',
#  '/srv/conda/envs/notebook/lib/python3.10/site-packages/vp4jl/nodeextension/image_conversion.json',
#  '/srv/conda/envs/notebook/lib/python3.10/site-packages/vp4jl/nodeextension/image visualization.json',
#  '/srv/conda/envs/notebook/lib/python3.10/site-packages/vp4jl/nodeextension/file.json',
#  '/srv/conda/envs/notebook/lib/python3.10/site-packages/vp4jl/nodeextension/torch.json',
#  '/srv/conda/envs/notebook/lib/python3.10/site-packages/vp4jl/nodeextension/imageio.json',
#  '/srv/conda/envs/notebook/lib/python3.10/site-packages/vp4jl/nodeextension/ndimage.json']

# %%
with open(nodes_lst[0], "r") as f:
    node_content = json.load(f)
node_content
# Out:
# {'description': 'Tensorflow Keras',
#  'enable': True,
#  'nodes': {'load_pytorch_model': {'type': 'load_pytorch_model',
#    'category': 'function',
#    'title': 'load_pytorch_model',
#    'externalImports': 'from torchvision import io\nfrom torchvision.io import ImageReadMode',
#    'sourceCode': "{{indent}}{{{outputs.1}}} = io.read_image({{{inputs.1}}}, {{{inputs.2}}})\n{{indent}}{{{outputs.1}}} = {'value': {{{outputs.1}}}, 'dataType': 'torch.tensor', 'metadata': {'colorChannel': 'rgb', 'channelOrder': 'channelFirst', 'isMiniBatched': False, 'intensityRange': '0-255', 'device': 'cpu'}}\n{{{outputs.0}}}",
#    'inputs': {'execIn': {'title': 'execIn',
#      'tooltip': 'execIn',
#      'dataType': 'exec',
#      'showWidget': False,
#      'showTitle': False},
#     'path': {'title': 'path',
#      'dataType': 'string',
#      'tooltip': 'path(str) - path of the model.'},
#     'eval': {'title': 'eval', 'dataType': 'boolean', 'defaultValue': True}},
# ...

# %%
with open(nodes_lst[1], "r") as f:
    node_content = json.load(f)
node_content
# Out:
# {'enable': True,
#  'nodes': {'ndarray * float': {'type': 'ndarray * float',
#    'category': 'math',
#    'title': '*',
#    'enableAddNewOne': True,
#    'sourceCode': '{{indent}}{{{outputs.0}}}=sum([{{{inputs}}}])',
#    'inputs': {'input1': {'dataType': 'numpy.ndarray',
#      'title': 'ndarray',
#      'showTitle': True},
#     'input2': {'dataType': 'float',
#      'defaultValue': 0,
#      'title': 'float',
#      'showTitle': True}},
#    'outputs': {'string': {'dataType': 'numpy.ndarray',
#      'title': 'ndarray',
#      'showTitle': True}}},
#   'astype': {'type': 'astype',
#    'category': 'math',
#    'title': '->',
#    'sourceCode': '{{indent}}{{{outputs.0}}}=float({{{inputs.0}}})',
#    'inputs': {'ndarray': {'dataType': 'numpy.ndarray',
#      'title': 'ndarray',
#      'showTitle': True},
#     'type': {'dataType': 'numpy.numpytype',
#      'title': 'type',
#      'default': 'numpytype.uint8'}},
#    'outputs': {'ndarray2': {'dataType': 'numpy.ndarray',
# ...

# %%
with open(nodes_lst[2], "r") as f:
    node_content = json.load(f)
node_content
# Out:
# {'description': 'Pathlib',
#  'enable': True,
#  'types': {'Path': {'default': '',
#    'widget': 'TextInput',
#    'shownInColor': 'hsl(30, 50%, 60%)'}},
#  'nodes': {'Create Path': {'type': 'Create Path',
#    'category': 'function',
#    'title': 'New Path',
#    'tooltip': 'create a Path object',
#    'externalImports': 'from pathlib import Path',
#    'sourceCode': '{{indent}}{{{outputs.1}}} = Path({{{inputs.1}}})\n{{{outputs.0}}}',
#    'inputs': {'execIn': {'title': 'execIn',
#      'tooltip': 'exec in',
#      'dataType': 'exec',
#      'showWidget': False,
#      'showTitle': False},
#     'input': {'title': 'string',
#      'dataType': 'string',
#      'tooltip': 'the path string to create'}},
#    'outputs': {'execOut': {'title': 'execOut',
#      'tooltip': 'exec out',
#      'dataType': 'exec',
#      'showWidget': False,
#      'showTitle': False},
#     'path': {'title': 'Path',
#      'dataType': 'Path.Path',
#      'tooltip': 'the Path object'}}},
# ...

# %%
with open(nodes_lst[3], "r") as f:
    node_content = json.load(f)
node_content
# Out:
# {'description': 'image conversion',
#  'enable': True,
#  'notShowInMenu': True,
#  'imageTypeConversion': {'imageTypes': [{'name': 'numpy.ndarray',
#     'functionName': 'numpy2numpy',
# ...

# %%
with open(nodes_lst[4], "r") as f:
    node_content = json.load(f)
node_content
# Out:
# {'description': 'os',
#  'enable': True,
#  'nodes': {'show_image': {'type': 'show_image',
#    'category': 'function',
#    'title': 'show_image',
#    'tooltip': 'Takes an input tensor in CHW layout and display it as an image',
#    'externalImports': 'from matplotlib import pyplot as plt',
#    'sourceCode': "{{indent}}def show_image(img, title=None, cmap=None, figSize=(9, 5)):\n    plt.figure(figsize=figSize)\n    plt.imshow(img, cmap=cmap)\n    plt.title(title)\n    plt.axis('off')\n    plt.show()\n{{indent}}show_image({{{inputs.1}}}, {{{inputs.2}}}, {{{inputs.3}}}, {{{inputs.4}}})\n{{{outputs.0}}}",
#    'inputs': {'execIn': {'title': 'execIn',
#      'tooltip': 'execIn',
#      'dataType': 'exec',
#      'showWidget': False,
#      'showTitle': False},
#     'image': {'title': 'image',
#      'dataType': 'image',
#      'defaultValue': {'dataType': 'numpy.ndarray',
#       'metadata': [{'colorChannel': 'rgb',
#         'isMiniBatched': False,
# ...

# %%
with open(nodes_lst[5], "r") as f:
    node_content = json.load(f)
node_content
# Out:
# {'enable': True,
#  'nodes': {'save_to_csv': {'type': 'save_to_csv',
#    'category': 'function',
#    'title': 'save_to_csv',
#    'externalImports': 'from torchvision import io',
#    'functionName': 'io.write_jpeg',
#    'inputs': {'execIn': {'title': 'execIn',
#      'tooltip': 'execIn',
#      'dataType': 'exec',
#      'showWidget': False,
#      'showTitle': False},
#     'path': {'title': 'path',
#      'dataType': 'string',
#      'defaultValue': 'untitled.csv'},
#     'pandas.dataframe': {'title': 'pandas dataframe',
#      'dataType': 'anyDataType',
#      'defaultValue': ''},
#     'sep': {'title': 'sep', 'dataType': 'string', 'defaultValue': "'\t'"}},
#    'outputs': {'execOut': {'title': 'execOut',
#      'tooltip': 'execOut',
#      'dataType': 'exec',
#      'showWidget': False,
#      'showTitle': False}}}}}

# %%
with open(nodes_lst[6], "r") as f:
    node_content = json.load(f)
node_content
# Out:
# {'description': 'The torch tensor type definition',
#  'enable': True,
#  'nodes': {'Stack': {'type': 'Stack',
#    'category': 'function',
#    'title': 'Stack',
#    'tooltip': 'Concatenates a sequence of tensors along a new dimension.',
#    'externalImports': 'import torch',
#    'sourceCode': '{{indent}}{{{outputs.1}}} = torch.stack({{{inputs.1}}})\n{{{outputs.0}}}',
#    'inputs': {'execIn': {'title': 'execIn',
#      'dataType': 'exec',
#      'showWidget': False,
#      'showTitle': False},
#     'input1': {'title': 'list or tensor',
#      'dataType': 'list',
#      'defaultValue': '[]'},
#     'input2': {'title': 'dim', 'dataType': 'integer', 'defaultValue': '0'}},
#    'outputs': {'execOut': {'title': 'execOut',
#      'dataType': 'exec',
#      'showWidget': False,
#      'showTitle': False},
#     'stackedtensor': {'title': 'stacked tensor',
#      'dataType': 'torch.tensor',
#      'defaultValue': '[]'}}},
#   'Slice': {'type': 'Slice',
#    'category': 'math',
# ...

# %%
with open(nodes_lst[7], "r") as f:
    node_content = json.load(f)
node_content
# Out:
# {'description': 'Image read and write functions from torchvision.io',
#  'enable': True,
#  'nodes': {'paths_to_images_in_folder': {'type': 'paths_to_images_in_folder',
#    'category': 'function',
#    'title': 'paths_to_images_in_folder',
#    'tooltip': 'Returns a list of paths to images in a given folder.',
#    'externalImports': 'from torchvision import io\nfrom torchvision.io import ImageReadMode',
#    'sourceCode': "{{indent}}{{{outputs.1}}} = io.read_image({{{inputs.1}}}, {{{inputs.2}}})\n{{indent}}{{{outputs.1}}} = {'value': {{{outputs.1}}}, 'dataType': 'torch.tensor', 'metadata': {'colorChannel': 'rgb', 'channelOrder': 'channelFirst', 'isMiniBatched': False, 'intensityRange': '0-255', 'device': 'cpu'}}\n{{{outputs.0}}}",
#    'inputs': {'execIn': {'title': 'execIn',
#      'tooltip': 'execIn',
#      'dataType': 'exec',
#      'showWidget': False,
#      'showTitle': False},
#     'path': {'title': 'path',
#      'dataType': 'string',
# ...

# %%
with open(nodes_lst[8], "r") as f:
    node_content = json.load(f)
node_content
# Out:
# {'enable': True,
#  'nodes': {'binary_fill_holes': {'type': 'binary_fill_holes',
#    'category': 'function',
#    'title': 'binary_fill_holes',
#    'externalImports': 'from skimage.peak_local_max import peak_local_max',
#    'sourceCode': "{{indent}}{{{outputs.1}}} =  peak_local_max({{{inputs.1}}})\n{{indent}}{{{outputs.1}}} = {'value': {{{outputs.1}}}[0], 'dataType': 'numpy.ndarray', 'metadata': {'colorChannel': 'grayscale', 'channelOrder': 'channelFirst', 'isMiniBatched': True, 'intensityRange': '0-1', 'device': 'cpu'}}\n{{{outputs.0}}}",
#    'inputs': {'execIn': {'title': 'execIn',
#      'dataType': 'exec',
#      'showWidget': False,
#      'showTitle': False},
#     'image': {'title': 'image',
#      'dataType': 'image',
#      'defaultValue': {'dataType': 'numpy.ndarray',
#       'metadata': [{'colorChannel': 'rgb',
#         'isMiniBatched': True,
#         'channelOrder': 'channelFirst',
#         'intensityRange': '0-255'},
#        {'colorChannel': 'grayscale',
# ...
