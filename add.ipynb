# %%
{"nodes":[{"id":"0","type":"Function & Variable Creation.new variable","position":{"x":366,"y":-11.399999999999977},"inputs":{"execIn":{"dataType":"exec"},"name":{"title":"name","value":"a","dataType":"anyDataType"},"value":{"title":"value","dataType":"anyDataType"}},"outputs":{"execOut":{"dataType":"exec"}},"title":"new variable"},{"id":"1","type":"Flow Control.main","position":{"x":30,"y":57},"outputs":{"execOut":{"dataType":"exec"}},"title":"main"},{"id":"2","type":"Function & Variable Creation.new variable","position":{"x":132,"y":66.00000000000003},"inputs":{"execIn":{"dataType":"exec"},"name":{"title":"name","value":"b","dataType":"anyDataType"},"value":{"title":"value","value":"2","dataType":"anyDataType"}},"outputs":{"execOut":{"dataType":"exec"}},"title":"new variable"},{"id":"4","type":"Function & Variable Creation.getter","position":{"x":573,"y":298.79999999999995},"outputs":{"getter":{"title":"a","value":"1","dataType":"anyDataType"}},"nodeRef":"0"},{"id":"3","type":"Operators.+","position":{"x":401,"y":177.79999999999995},"inputs":{"in1":{"title":"in","value":"1","dataType":"anyDataType"},"in2":{"value":"2","dataType":"anyDataType"}},"outputs":{"out":{"title":"out","dataType":"anyDataType"}},"dataType":"anyDataType","title":"+"}],"edges":[{"id":"reactflow__edge-1execOut-2execIn","output":"1","input":"2","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-2execOut-0execIn","output":"2","input":"0","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-3out-0value","output":"3","input":"0","outputHandle":"out","inputHandle":"value","dataType":"anyDataType","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 50%)"}}]}

# %%
globals()['In'][1].split("\n")
# Out:
# ['b = 2', 'n_3_out = 1 + 2', 'a = n_3_out']
